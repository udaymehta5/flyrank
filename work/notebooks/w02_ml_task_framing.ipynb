# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/udaymehta5/flyrank/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My Lane as an ML Task
#
# **Task type:** Clustering (unsupervised)
#
# Structural Content Archetype Clustering groups pages into archetypes based
# on structural features — not a labeled prediction task. There is no
# "correct answer" per page; the goal is to discover natural groupings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or Proxy
#
# **Proxy:** Cluster assignment (which archetype a page belongs to), derived
# from structural features: `word_count`, `char_count`, `content_type`,
# `position_tier`, `main_intent`.
#
# There is no ground-truth label — the proxy is the cluster label the model
# assigns based on feature similarity.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success Metric
#
# **Primary metric:** Silhouette score — measures how well-separated and
# internally consistent the clusters are.
#
# **Practical check:** Whether clusters show meaningfully different
# performance (e.g. average `ctr`, `engagement_rate`) — if all clusters
# perform the same, the grouping isn't useful even if silhouette score is high.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# !git clone https://github.com/udaymehta5/flyrank.git
# %cd flyrank
# Out:
# Cloning into 'flyrank'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 134 (delta 46), reused 93 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (134/134), 1.85 MiB | 8.60 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /content/flyrank

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# One row = one content page
unit_df = df[["content_id", "content_type", "word_count", "position_tier",
              "ctr", "engagement_rate"]]

print(unit_df.shape)
unit_df.head()
# Out:
# (30000, 6)
#              content_id     content_type  word_count position_tier   ctr  \
# 0  content_304f48230142  keyword article      3221.0      striking  0.76
# 1  content_a1fb4e703a9e  keyword article      2481.0      page_3_5  0.05
# 2  content_9aa793d4d895  keyword article      3515.0      page_3_5  0.09
# 3  content_331d6c4de07b  keyword article         NaN        page_1  0.49
# 4  content_d99b7a2d90ca  keyword article      2803.0      page_3_5  0.13
#
#    engagement_rate
# 0             5.88
# 1             0.00
# 2             0.00
# 3             1.28
# 4             0.00

# %%
# Placeholder — real cluster labels will come from an unsupervised model
# in a later week
unit_df["archetype_cluster"] = None
unit_df.head()
# Out:
# /tmp/ipykernel_701/283840488.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unit_df["archetype_cluster"] = None
#              content_id     content_type  word_count position_tier   ctr  \
# 0  content_304f48230142  keyword article      3221.0      striking  0.76
# 1  content_a1fb4e703a9e  keyword article      2481.0      page_3_5  0.05
# 2  content_9aa793d4d895  keyword article      3515.0      page_3_5  0.09
# 3  content_331d6c4de07b  keyword article         NaN        page_1  0.49
# 4  content_d99b7a2d90ca  keyword article      2803.0      page_3_5  0.13
#
#    engagement_rate archetype_cluster
# 0             5.88              None
# 1             0.00              None
# 2             0.00              None
# ...

# %% [markdown]
# ## 5. Why ML Beats a Fixed Rule
#
# Archetypes emerge from the interaction of multiple structural features at
# once — word count, position tier, content type, and engagement together.
# No single threshold or if/else rule can capture this combined pattern.
# An unsupervised clustering algorithm is needed to reveal groupings that
# wouldn't be visible by manually inspecting one column at a time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 6. Self-Check
#
# - [x] Named the ML task type (clustering).
# - [x] Named the target/proxy (cluster assignment from structural features).
# - [x] Named the success metric (silhouette score + performance differentiation).
# - [x] Showed the unit of analysis as a real dataframe (one row = one page).
# - [x] Explained why this is an ML problem, not a fixed rule.
# - [x] Tied the output to a real action (prioritizing restructuring for
#       low-performing archetypes).
